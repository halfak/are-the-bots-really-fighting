# %%
# !pip install mwapi pandas seaborn 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import mwapi
# %matplotlib inline
# Out:
# Requirement already satisfied: mwapi in /home/staeiou/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: pandas in /home/staeiou/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: seaborn in /home/staeiou/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests in /home/staeiou/anaconda3/lib/python3.6/site-packages (from mwapi)
# Requirement already satisfied: python-dateutil>=2 in /home/staeiou/anaconda3/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: pytz>=2011k in /home/staeiou/anaconda3/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: numpy>=1.7.0 in /home/staeiou/anaconda3/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: six>=1.5 in /home/staeiou/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2->pandas)

# %%
en_df = pd.read_csv("../../datasets/enwiki_20161201_reverted_bot2bot.tsv", sep="\t")

# %%
len(en_df)
# Out:
# 1001093

# %%
en_df[0:2].transpose()
# Out:
#                                                     0  \
# rev_id                                      273691771
# rev_timestamp                          20090227173507
# rev_user                                      6505923
# rev_user_text                               Kbdankbot
# rev_page                                      5040439
# rev_sha1              qj45ne2z4yfexmpaz5wfnbm2yrmqt4j
# rev_minor_edit                                  False
# rev_deleted                                     False
# rev_parent_id                             2.59117e+08
# archived                                        False
# reverting_id                                273789753
# reverting_timestamp                    20090228021925
# reverting_user                                1215485
# reverting_user_text                           Cydebot
# reverting_page                                5040439
# reverting_sha1        od1e685o9f5j7dtpd9zp2fhew3agjeq
# reverting_minor_edit                             True
# reverting_deleted                               False
# reverting_parent_id                       2.73692e+08
# reverting_archived                              False
# rev_revert_offset                                   1
# revisions_reverted                                  1
# reverted_to_rev_id                          259117355
# page_namespace                                      0
#
#                                                     1
# rev_id                                      136526894
# rev_timestamp                          20070607044209
# rev_user                                      4534303
# rev_user_text                                   PbBot
# rev_page                                      3046554
# rev_sha1              3xtnw7u4w9h6cg1smw97mqnr1en6a55
# rev_minor_edit                                  False
# rev_deleted                                     False
# rev_parent_id                             1.20932e+08
# archived                                        False
# reverting_id                                269875438
# reverting_timestamp                    20090210230337
# reverting_user                                7328338
# reverting_user_text                             Yobot
# reverting_page                                3046554
# reverting_sha1        f8ye1kj73h0ymwqj6rlsimwk3jd9tef
# reverting_minor_edit                             True
# reverting_deleted                               False
# reverting_parent_id                       1.36527e+08
# reverting_archived                              False
# rev_revert_offset                                   1
# revisions_reverted                                  1
# reverted_to_rev_id                          120932016
# page_namespace                                      1

# %% [markdown]
# ### Convert timestamps

# %%
en_df['reverting_timestamp_dt'] = pd.to_datetime(en_df['reverting_timestamp'], format="%Y%m%d%H%M%S")
en_df['reverted_timestamp_dt'] = pd.to_datetime(en_df['rev_timestamp'], format="%Y%m%d%H%M%S")

en_df = en_df.set_index('reverting_timestamp_dt')

en_df['reverting_timestamp_dt'] = pd.to_datetime(en_df['reverting_timestamp'], format="%Y%m%d%H%M%S")

# %% [markdown]
# ### Top reverting bots, ns0

# %%
en_df[en_df['page_namespace']==0]['reverting_user_text'].value_counts()[0:50]
# Out:
# Addbot            152226
# Xqbot              80192
# AvicBot            50438
# EmausBot           46648
# RussBot            16138
# Invadibot          11888
# タチコマ robot          9946
# AvocatoBot          9394
# DarknessBot         8004
# VolkovBot           5920
# DumbBOT             5674
# Cydebot             4150
# Redirect fixer      4086
# KLBot2              4032
# MystBot             3746
# Escarbot            3584
# ChuispastonBot      3310
# Scepbot             3216
# WikitanvirBot       2928
# MastiBot            2502
# SassoBot            2396
# KasparBot           2134
# PixelBot            2096
# Muro Bot            1956
# SieBot              1818
# RedBot              1806
# JAnDbot             1792
# ZéroBot             1736
# JL-Bot              1626
# EdoBot              1312
# JYBot               1204
# Fluxbot             1178
# Mathbot             1062
# Luckas-bot          1002
# Ripchip Bot          934
# ArthurBot            916
# SoxBot               884
# Dexbot               872
# TXiKiBoT             860
# Thijs!bot            858
# DSisyphBot           818
# Alexbot              810
# RibotBOT             734
# Ptbotgourou          732
# 718 Bot              710
# Chobot               690
# MetsBot              668
# MerlIwBot            642
# STBot                628
# Legobot              614
# Name: reverting_user_text, dtype: int64

# %% [markdown]
# ### Top reverted bots

# %%
en_df[en_df['page_namespace']==0]['rev_user_text'].value_counts()[0:50]
# Out:
# EmausBot              67544
# Xqbot                 62314
# AvicBot               39626
# RussBot               34948
# ZéroBot               33798
# Luckas-bot            13946
# DarknessBot           11952
# TuHan-Bot             10710
# タチコマ robot            10502
# Invadibot              9792
# VolkovBot              8654
# Makecat-bot            8621
# AvocatoBot             8342
# Redirect fixer         7814
# Thijs!bot              7696
# Zorrobot               7516
# SieBot                 6014
# FoxBot                 5886
# Lowercase sigmabot     5592
# MystBot                5398
# Scepbot                4690
# WikitanvirBot          4674
# YFdyh-bot              4481
# Addbot                 4330
# HRoestBot              3774
# JackieBot              3526
# Muro Bot               3346
# ChuispastonBot         3160
# LaaknorBot             3062
# RedBot                 2928
# JYBot                  2906
# Cydebot                2846
# GrouchoBot             2734
# TXiKiBoT               2690
# SteenthIWbot           2392
# DSisyphBot             2164
# KamikazeBot            2144
# LucienBOT              2142
# RjwilmsiBot            2140
# ArthurBot              1972
# Alexbot                1968
# Ptbotgourou            1748
# ArmbrustBot            1598
# CarsracBot             1546
# JAnDbot                1540
# Amirobot               1536
# Ripchip Bot            1434
# PixelBot               1374
# GreenC bot             1198
# MetsBot                1182
# Name: rev_user_text, dtype: int64

# %% [markdown]
# ### Reverting/reverted bot pairs

# %%
en_df['bot_pair'] = en_df['reverting_user_text'] + " reverting " + en_df['rev_user_text']

# %%
en_df[en_df['page_namespace']==0]['bot_pair'].value_counts()[0:50]
# Out:
# Addbot reverting EmausBot               31002
# Addbot reverting ZéroBot                26220
# AvicBot reverting Xqbot                 22688
# Xqbot reverting AvicBot                 21978
# EmausBot reverting Xqbot                14006
# AvicBot reverting EmausBot              12282
# Xqbot reverting RussBot                 11536
# Xqbot reverting EmausBot                10814
# Addbot reverting TuHan-Bot               9012
# Xqbot reverting DarknessBot              8080
# Addbot reverting Luckas-bot              7916
# EmausBot reverting AvicBot               7502
# Xqbot reverting Invadibot                7342
# Addbot reverting Makecat-bot             6833
# Addbot reverting Zorrobot                6542
# Addbot reverting Thijs!bot               6090
# Invadibot reverting Xqbot                6076
# DumbBOT reverting Lowercase sigmabot     5578
# Addbot reverting SieBot                  4130
# タチコマ robot reverting RussBot             4002
# AvocatoBot reverting AvicBot             3836
# AvicBot reverting AvocatoBot             3802
# Addbot reverting MystBot                 3682
# AvicBot reverting RussBot                3468
# Addbot reverting YFdyh-bot               3445
# DarknessBot reverting Xqbot              3384
# EmausBot reverting ZéroBot               3358
# Xqbot reverting タチコマ robot               3302
# Xqbot reverting Redirect fixer           2878
# AvocatoBot reverting Xqbot               2736
# Addbot reverting JackieBot               2640
# Invadibot reverting AvicBot              2614
# Addbot reverting Xqbot                   2536
# Redirect fixer reverting RussBot         2524
# RussBot reverting タチコマ robot             2498
# Xqbot reverting VolkovBot                2422
# VolkovBot reverting Xqbot                2418
# Addbot reverting VolkovBot               2344
# Addbot reverting HRoestBot               2342
# Addbot reverting WikitanvirBot           2286
# RussBot reverting Xqbot                  2164
# RussBot reverting Cydebot                2154
# AvicBot reverting Invadibot              2110
# Addbot reverting LaaknorBot              2088
# Addbot reverting SteenthIWbot            2086
# Cydebot reverting RussBot                2078
# Scepbot reverting RussBot                2010
# DarknessBot reverting RussBot            1992
# Xqbot reverting AvocatoBot               1918
# KasparBot reverting RjwilmsiBot          1878
# Name: bot_pair, dtype: int64

# %% [markdown]
# ## Proportion of total edits that were bot-bot reverts/reverted

# %% [markdown]
# ### Get list of all bots

# %%
all_reverted_bots = en_df['rev_user_text'].unique()
len(all_reverted_bots)
# Out:
# 671

# %%
all_reverting_bots = en_df['reverting_user_text'].unique()
len(all_reverting_bots)
# Out:
# 527

# %%
all_bots = list(set(all_reverting_bots).union(set(all_reverted_bots)))
len(all_bots)
# Out:
# 750

# %% [markdown]
# ### Get total edit count for each bot

# %%
session = mwapi.Session('https://en.wikipedia.org', user_agent="Edit count script by User:Staeiou")

result = []
for count in range(0,round(len(all_bots)/50)+1):
    start = count * 50
    end = start + 50
    result.append(session.get(action='query', list='users', ususers=all_bots[start:end], usprop='editcount'))

# %%
bot_editcount = {}
for x1 in result:
    for x2 in x1['query']['users']:
        bot_editcount[x2['name']] = x2['editcount']
        #print(x2['name'], x2['editcount'])

# %%
bot_editcount_df = pd.DataFrame.from_dict(bot_editcount, orient='index')
bot_editcount_df.sort_values(by=0, ascending=False)[0:25]
# Out:
#                                   0
# Cydebot                     5709990
# WP 1.0 bot                  5494319
# Yobot                       4651415
# ClueBot NG                  4408957
# SmackBot                    3734324
# Addbot                      2838809
# AnomieBOT                   2836850
# SineBot                     2099708
# EmausBot                    1671243
# MediaWiki message delivery  1629233
# RjwilmsiBot                 1602950
# ClueBot                     1596818
# KasparBot                   1547774
# Xqbot                       1526766
# RussBot                     1231871
# BG19bot                     1005055
# Fbot                         960904
# BattyBot                     960497
# The Anomebot2                943350
# BetacommandBot               931490
# Luckas-bot                   929662
# Legobot                      926809
# SporkBot                     837576
# AvicBot                      817979
# Lightbot                     791863

# %%
bot_editcount_df.ix['Cydebot'][0]
# Out:
# 5709990

# %%
reverting_bot_counts = en_df['reverting_user_text'].value_counts()
reverted_bot_counts = en_df['rev_user_text'].value_counts()

# %% [markdown]
# ### Percent of edits each bot made that were reverting another bot

# %%
reverting_df = pd.DataFrame(columns=['user', 'total_edits', 'reverting_bot_edits', 'prop_bot_revert'])
for bot_user in reverting_bot_counts.index:
    #print(bot_user, round(reverting_bot_counts[bot_user]/bot_editcount_df.ix[bot_user][0],3)*100, "%")
    row_d = {'user' : bot_user,
             'total_edits' : bot_editcount_df.ix[bot_user][0],
             'reverting_bot_edits' : reverting_bot_counts[bot_user],
             'prop_bot_revert' : reverting_bot_counts[bot_user]/bot_editcount_df.ix[bot_user][0]}
    reverting_df = reverting_df.append(row_d, ignore_index=True)

reverting_df = reverting_df.set_index('user')

# %%
reverting_df[0:5]
# Out:
#                     total_edits  reverting_bot_edits  prop_bot_revert
# user
# Addbot                2838809.0             291629.0         0.102729
# Xqbot                 1526766.0              90220.0         0.059092
# EmausBot              1671243.0              74570.0         0.044619
# AvicBot                817979.0              57844.0         0.070716
# HBC AIV helperbot7     253005.0              56408.0         0.222952

# %% [markdown]
# ### Percent of edits each bot made that were reverted by another bot

# %%
reverted_df = pd.DataFrame(columns=['user', 'total_edits', 'reverted_bot_edits', 'prop_bot_reverted'])

for bot_user in reverted_bot_counts.index:
    #print(bot_user, round(reverted_bot_counts[bot_user]/bot_editcount_df.ix[bot_user][0],3)*100, "%")
    row_d = {'user' : bot_user,
             'total_edits' : bot_editcount_df.ix[bot_user][0],
             'reverted_bot_edits' : reverted_bot_counts[bot_user],
             'prop_bot_reverted' : reverted_bot_counts[bot_user]/bot_editcount_df.ix[bot_user][0]}
    reverted_df = reverted_df.append(row_d, ignore_index=True)
    
reverted_df = reverted_df.set_index('user')

# %%
reverted_df[0:5]
# Out:
#             total_edits  reverted_bot_edits  prop_bot_reverted
# user
# EmausBot      1671243.0            108569.0           0.064963
# Xqbot         1526766.0             72936.0           0.047772
# ZéroBot        704777.0             61450.0           0.087191
# ClueBot NG    4408957.0             47680.0           0.010814
# AvicBot        817979.0             46484.0           0.056828

# %% [markdown]
# #### Join dataframes
#
# TODO: fix

# %%
pd.concat([reverting_df, reverted_df], axis=1)
#reverting_df.join(reverted_df, how='outer', on='index')
# Out:
#                                   total_edits  reverting_bot_edits  \
# .anacondabot                          25534.0                 28.0
# 28bot                                 93387.0                 20.0
# 3RRBot                                 3841.0                  2.0
# 718 Bot                               99574.0                724.0
# A4bot                                 25852.0                  8.0
# ABot                                      NaN                  NaN
# AEBot                                    10.0                  2.0
# AHbot                                     NaN                  NaN
# AIDbot                                  507.0                 14.0
# AMbot                                     NaN                  NaN
# AVBOT                                  2098.0                  2.0
# AZPR                                   2879.0                  2.0
# Addbot                              2838809.0             291629.0
# Addihockey10 (automated)                  NaN                  NaN
# Adlerbot                               3842.0                 32.0
# AftabBot                                  NaN                  NaN
# Aka                                     564.0                  6.0
# AkhtaBot                              10976.0                 22.0
# Aksibot                                   NaN                  NaN
# Alaibot                              434501.0                  2.0
# Albambot                               2977.0                  4.0
# AlexNewArtBot                        778467.0                  2.0
# Alexbot                              196144.0               1436.0
# Alirezabot                                NaN                  NaN
# AlleborgoBot                          94853.0                336.0
# Almabot                               12592.0                 90.0
# AlmoullimBOT                              NaN                  NaN
# AlnoktaBOT                            19917.0                470.0
# Alph Bot                              16072.0                288.0
# Alphachimpbot                             NaN                  NaN
# ...                                       ...                  ...
# WuBot                                  4125.0                 96.0
# Wybot                                     NaN                  NaN
# XLinkBot                             604517.0                  4.0
# XZeroBot                               4901.0                 52.0
# XaxaBot                                   NaN                  NaN
# XeBot                                   237.0                  2.0
# Xenobot                              197501.0               1768.0
# Xenobot Mk V                         393887.0                  8.0
# Xqbot                               1526766.0              90220.0
# Xwbot                                     NaN                  NaN
# XyBot                                 16275.0                 54.0
# YFdyh-bot                            166786.0                150.0
# YasBot                                    NaN                  NaN
# Yet Another Redirect Cleanup Bot       1235.0                  2.0
# Yetanotherbot                           905.0                322.0
# YiFeiBot                              27316.0                262.0
# Yobot                               4651415.0               7624.0
# YonaBot                                5580.0                 12.0
# Yonidebot                              3147.0                 36.0
# YurikBot                             278165.0                204.0
# Z-BOT                                     NaN                  NaN
# ZedlikBot                               120.0                  2.0
# Zorrobot                             142590.0                348.0
# Zwobot                                18852.0                 14.0
# Zxabot                                 1835.0                  8.0
# Zyxwvut-Bot                             830.0                  2.0
# ZéroBot                              704777.0               2024.0
# ^demonBot2                            23458.0                 16.0
# جار الله                                 58.0                  2.0
# タチコマ robot                           161037.0              10858.0
#
#                                   prop_bot_revert  total_edits  \
# .anacondabot                             0.001097      25534.0
# 28bot                                    0.000214      93387.0
# 3RRBot                                   0.000521          NaN
# 718 Bot                                  0.007271      99574.0
# A4bot                                    0.000309      25852.0
# ABot                                          NaN       1372.0
# AEBot                                    0.200000          NaN
# AHbot                                         NaN        425.0
# AIDbot                                   0.027613        507.0
# AMbot                                         NaN      30053.0
# AVBOT                                    0.000953          NaN
# AZPR                                     0.000695          NaN
# Addbot                                   0.102729    2838809.0
# Addihockey10 (automated)                      NaN       1003.0
# Adlerbot                                 0.008329       3842.0
# AftabBot                                      NaN         20.0
# Aka                                      0.010638          NaN
# AkhtaBot                                 0.002004      10976.0
# Aksibot                                       NaN       7808.0
# Alaibot                                  0.000005     434501.0
# Albambot                                 0.001344       2977.0
# AlexNewArtBot                            0.000003          NaN
# Alexbot                                  0.007321     196144.0
# Alirezabot                                    NaN        885.0
# AlleborgoBot                             0.003542      94853.0
# Almabot                                  0.007147      12592.0
# AlmoullimBOT                                  NaN          1.0
# AlnoktaBOT                               0.023598      19917.0
# Alph Bot                                 0.017919      16072.0
# Alphachimpbot                                 NaN     100435.0
# ...                                           ...          ...
# WuBot                                    0.023273       4125.0
# Wybot                                         NaN       1541.0
# XLinkBot                                 0.000007     604517.0
# XZeroBot                                 0.010610       4901.0
# XaxaBot                                       NaN          4.0
# XeBot                                    0.008439          NaN
# Xenobot                                  0.008952     197501.0
# Xenobot Mk V                             0.000020     393887.0
# Xqbot                                    0.059092    1526766.0
# Xwbot                                         NaN         47.0
# XyBot                                    0.003318          NaN
# YFdyh-bot                                0.000899     166786.0
# YasBot                                        NaN        491.0
# Yet Another Redirect Cleanup Bot         0.001619          NaN
# Yetanotherbot                            0.355801        905.0
# YiFeiBot                                 0.009591      27316.0
# Yobot                                    0.001639    4651415.0
# YonaBot                                  0.002151       5580.0
# Yonidebot                                0.011439       3147.0
# YurikBot                                 0.000733     278165.0
# Z-BOT                                         NaN         55.0
# ZedlikBot                                0.016667          NaN
# Zorrobot                                 0.002441     142590.0
# Zwobot                                   0.000743      18852.0
# Zxabot                                   0.004360       1835.0
# Zyxwvut-Bot                              0.002410        830.0
# ZéroBot                                  0.002872     704777.0
# ^demonBot2                               0.000682          NaN
# جار الله                                 0.034483          NaN
# タチコマ robot                               0.067425     161037.0
#
#                                   reverted_bot_edits  prop_bot_reverted
# .anacondabot                                    52.0           0.002037
# 28bot                                           14.0           0.000150
# 3RRBot                                           NaN                NaN
# 718 Bot                                         10.0           0.000100
# A4bot                                          152.0           0.005880
# ABot                                             4.0           0.002915
# AEBot                                            NaN                NaN
# AHbot                                           36.0           0.084706
# AIDbot                                          24.0           0.047337
# AMbot                                            2.0           0.000067
# AVBOT                                            NaN                NaN
# AZPR                                             NaN                NaN
# Addbot                                        5092.0           0.001794
# Addihockey10 (automated)                         4.0           0.003988
# Adlerbot                                        22.0           0.005726
# AftabBot                                         2.0           0.100000
# Aka                                              NaN                NaN
# AkhtaBot                                        46.0           0.004191
# Aksibot                                          8.0           0.001025
# Alaibot                                         24.0           0.000055
# Albambot                                        30.0           0.010077
# AlexNewArtBot                                    NaN                NaN
# Alexbot                                       6432.0           0.032792
# Alirezabot                                     290.0           0.327684
# AlleborgoBot                                   410.0           0.004322
# Almabot                                        196.0           0.015565
# AlmoullimBOT                                     2.0           2.000000
# AlnoktaBOT                                      70.0           0.003515
# Alph Bot                                       792.0           0.049278
# Alphachimpbot                                   16.0           0.000159
# ...                                              ...                ...
# WuBot                                          270.0           0.065455
# Wybot                                           10.0           0.006489
# XLinkBot                                       834.0           0.001380
# XZeroBot                                       110.0           0.022444
# XaxaBot                                          2.0           0.500000
# XeBot                                            NaN                NaN
# Xenobot                                        114.0           0.000577
# Xenobot Mk V                                  1742.0           0.004423
# Xqbot                                        72936.0           0.047772
# Xwbot                                            2.0           0.042553
# XyBot                                            NaN                NaN
# YFdyh-bot                                     9675.0           0.058008
# YasBot                                          48.0           0.097760
# Yet Another Redirect Cleanup Bot                 NaN                NaN
# Yetanotherbot                                   50.0           0.055249
# YiFeiBot                                       170.0           0.006223
# Yobot                                         2132.0           0.000458
# YonaBot                                         30.0           0.005376
# Yonidebot                                       30.0           0.009533
# YurikBot                                       282.0           0.001014
# Z-BOT                                           70.0           1.272727
# ZedlikBot                                        NaN                NaN
# Zorrobot                                     11437.0           0.080209
# Zwobot                                          28.0           0.001485
# Zxabot                                           4.0           0.002180
# Zyxwvut-Bot                                      2.0           0.002410
# ZéroBot                                      61450.0           0.087191
# ^demonBot2                                       NaN                NaN
# جار الله                                         NaN                NaN
# タチコマ robot                                   11490.0           0.071350
#
# [750 rows x 6 columns]
