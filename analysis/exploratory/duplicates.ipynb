# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Data processing

# %%
glob.glob("../../datasets/*bot2bot.tsv")
# Out:
# ['../../datasets/enwiki_20161201_reverted_bot2bot.tsv',
#  '../../datasets/zhwiki_20161001_reverted_bot2bot.tsv',
#  '../../datasets/frwiki_20161001_reverted_bot2bot.tsv',
#  '../../datasets/jawiki_20161001_reverted_bot2bot.tsv',
#  '../../datasets/eswiki_20161001_reverted_bot2bot.tsv',
#  '../../datasets/ptwiki_20161001_reverted_bot2bot.tsv',
#  '../../datasets/dewiki_20161001_reverted_bot2bot.tsv']

# %%
df_dict = {}
for filename in glob.glob("../../datasets/*bot2bot.tsv"):
    lang_code = filename[15:17]
    df_dict[lang_code] = pd.read_csv(filename, sep="\t")

# %%
for lang, lang_df in df_dict.items():
    print(lang, len(lang_df))
# Out:
# de 137844
# pt 141738
# en 1001093
# zh 102846
# es 177368
# ja 89980
# fr 193066

# %%
df_dict['en'][0:2].transpose()
# Out:
#                                                                       0  \
# rev_id                                                        273691771
# rev_timestamp                                            20090227173507
# rev_user                                                        6505923
# rev_user_text                                                 Kbdankbot
# rev_page                                                        5040439
# rev_sha1                                qj45ne2z4yfexmpaz5wfnbm2yrmqt4j
# rev_minor_edit                                                    False
# rev_deleted                                                       False
# rev_parent_id                                               2.59117e+08
# archived                                                          False
# reverting_id                                                  273789753
# reverting_timestamp                                      20090228021925
# reverting_user                                                  1215485
# reverting_user_text                                             Cydebot
# reverting_page                                                  5040439
# reverting_sha1                          od1e685o9f5j7dtpd9zp2fhew3agjeq
# reverting_minor_edit                                               True
# reverting_deleted                                                 False
# reverting_parent_id                                         2.73692e+08
# reverting_archived                                                False
# reverting_comment     Robot - Speedily moving category 9th-century i...
# rev_revert_offset                                                     1
# revisions_reverted                                                    1
# reverted_to_rev_id                                            259117355
# page_namespace                                                        0
#
#                                                                       1
# rev_id                                                        136526894
# rev_timestamp                                            20070607044209
# rev_user                                                        4534303
# rev_user_text                                                     PbBot
# rev_page                                                        3046554
# rev_sha1                                3xtnw7u4w9h6cg1smw97mqnr1en6a55
# rev_minor_edit                                                    False
# rev_deleted                                                       False
# rev_parent_id                                               1.20932e+08
# archived                                                          False
# reverting_id                                                  269875438
# reverting_timestamp                                      20090210230337
# reverting_user                                                  7328338
# reverting_user_text                                               Yobot
# reverting_page                                                  3046554
# reverting_sha1                          f8ye1kj73h0ymwqj6rlsimwk3jd9tef
# reverting_minor_edit                                               True
# reverting_deleted                                                 False
# reverting_parent_id                                         1.36527e+08
# reverting_archived                                                False
# reverting_comment     Removing {{1911 talk}} per [[Wikipedia:Templat...
# rev_revert_offset                                                     1
# revisions_reverted                                                    1
# reverted_to_rev_id                                            120932016
# page_namespace                                                        1

# %% [markdown]
# ### Look for duplicates

# %%
df_dict['en'].query("rev_page ==12")
# Out:
#         rev_id   rev_timestamp  rev_user  rev_user_text  rev_page  \
# 185  396300331  20101112114014  11340674  WikitanvirBot        12
# 186  396304452  20101112121743   3035831      VolkovBot        12
# 191  396300331  20101112114014  11340674  WikitanvirBot        12
# 192  396304452  20101112121743   3035831      VolkovBot        12
#
#                             rev_sha1 rev_minor_edit rev_deleted  \
# 185  e75plyc598xvr9trp4edsu8l8g65d81           True       False
# 186  k8fcg4msl50tfo5n3kx3e834ej59zp1           True       False
# 191  e75plyc598xvr9trp4edsu8l8g65d81           True       False
# 192  k8fcg4msl50tfo5n3kx3e834ej59zp1           True       False
#
#      rev_parent_id archived  reverting_id  reverting_timestamp  \
# 185    396211399.0    False     396304452       20101112121743
# 186    396300331.0    False     396329931       20101112151912
# 191    396211399.0    False     396304452       20101112121743
# 192    396300331.0    False     396329931       20101112151912
#
#      reverting_user reverting_user_text  reverting_page  \
# 185         3035831           VolkovBot              12
# 186        13177883            Mjbmrbot              12
# 191         3035831           VolkovBot              12
# 192        13177883            Mjbmrbot              12
#
#                       reverting_sha1 reverting_minor_edit reverting_deleted  \
# 185  k8fcg4msl50tfo5n3kx3e834ej59zp1                 True             False
# 186  e75plyc598xvr9trp4edsu8l8g65d81                 True             False
# 191  k8fcg4msl50tfo5n3kx3e834ej59zp1                 True             False
# 192  e75plyc598xvr9trp4edsu8l8g65d81                 True             False
#
#      reverting_parent_id reverting_archived  \
# 185          396300331.0              False
# 186          396304452.0              False
# 191          396300331.0              False
# 192          396304452.0              False
#
#                        reverting_comment  rev_revert_offset  \
# 185     robot Modifying: [[fa:آنارشیسم]]                  1
# 186  robot Modifying: [[fa:اقتدارگریزی]]                  1
# 191     robot Modifying: [[fa:آنارشیسم]]                  1
# 192  robot Modifying: [[fa:اقتدارگریزی]]                  1
#
#      revisions_reverted  reverted_to_rev_id  page_namespace
# 185                   1           396211399               0
# 186                   1           396300331               0
# 191                   1           396211399               0
# 192                   1           396300331               0

# %%
df_dict['en'].query("rev_page ==12").drop_duplicates()
# Out:
#         rev_id   rev_timestamp  rev_user  rev_user_text  rev_page  \
# 185  396300331  20101112114014  11340674  WikitanvirBot        12
# 186  396304452  20101112121743   3035831      VolkovBot        12
#
#                             rev_sha1 rev_minor_edit rev_deleted  \
# 185  e75plyc598xvr9trp4edsu8l8g65d81           True       False
# 186  k8fcg4msl50tfo5n3kx3e834ej59zp1           True       False
#
#      rev_parent_id archived  reverting_id  reverting_timestamp  \
# 185    396211399.0    False     396304452       20101112121743
# 186    396300331.0    False     396329931       20101112151912
#
#      reverting_user reverting_user_text  reverting_page  \
# 185         3035831           VolkovBot              12
# 186        13177883            Mjbmrbot              12
#
#                       reverting_sha1 reverting_minor_edit reverting_deleted  \
# 185  k8fcg4msl50tfo5n3kx3e834ej59zp1                 True             False
# 186  e75plyc598xvr9trp4edsu8l8g65d81                 True             False
#
#      reverting_parent_id reverting_archived  \
# 185          396300331.0              False
# 186          396304452.0              False
#
#                        reverting_comment  rev_revert_offset  \
# 185     robot Modifying: [[fa:آنارشیسم]]                  1
# 186  robot Modifying: [[fa:اقتدارگریزی]]                  1
#
#      revisions_reverted  reverted_to_rev_id  page_namespace
# 185                   1           396211399               0
# 186                   1           396300331               0

# %%
print(len(df_dict['en']))
print(len(df_dict['en'].drop_duplicates()))
# Out:
# 1001093
# 500553

# %%
print(len(df_dict['ja']))
print(len(df_dict['ja'].drop_duplicates()))
# Out:
# 89980
# 44990

# %% [markdown]
# ### Combining into one dataframe

# %%
df_all = df_dict['en'].copy()
df_all = df_all.drop(df_all.index, axis=0)

for lang, lang_df in df_dict.items():
    lang_df['language'] = lang
    df_all = pd.concat([df_all, lang_df])

# %%
df_all['language'].value_counts()
# Out:
# en    1001093
# fr     193066
# es     177368
# pt     141738
# de     137844
# zh     102846
# ja      89980
# Name: language, dtype: int64

# %%
for lang, lang_df in df_dict.items():
    print(lang, len(lang_df))
# Out:
# de 137844
# pt 141738
# en 1001093
# zh 102846
# es 177368
# ja 89980
# fr 193066

# %%
print(len(df_all))
print(len(df_all.drop_duplicates()))
# Out:
# 1843935
# 921974
