# %%
library(data.table)
library(ggplot2)

dt = data.table(read.table("../../datasets/enwiki_20161201_reverted_bot2bot.tsv.bz2", sep="\t", header=T, quote="",
                          comment.char=""))
dt$rev_ts = as.POSIXct(format(dt$rev_timestamp, scientific=F), format="%Y%m%d%H%M%S")
dt$rev_month = as.Date(paste(format(dt$rev_ts, "%Y-%m-"), "01", sep=""))
dt$rev_day = as.Date(dt$rev_ts)
dt$reverting_ts = as.POSIXct(format(dt$reverting_timestamp, scientific=F), format="%Y%m%d%H%M%S")
dt$reverting_month = as.Date(paste(format(dt$reverting_ts, "%Y-%m-"), "01", sep=""))
dt$reverting_day = as.Date(dt$reverting_ts)

# %%
# From https://quarry.wmflabs.org/query/18187
redirect_pages = c(2991127,
2991195,
2991200,
2991205,
2991208,
2991211,
2994450,
3080753,
13148847,
15333324,
18313488,
18322006,
27530926,
28734823,
28734827,
28734832,
28734842,
28734845,
32089263,
32157222,
33089039,
33445966,
33681103,
36233196,
36233198,
36233202,
36233203,
36233205,
36233208,
36233209,
36233210,
36233212,
36233213,
36233215,
36233216,
36233221,
36233222,
36233223,
36233225,
36233226,
49828376,
50552336,
50754668,
51337448,
51998441,
51999533,
52320520)

# %%
fight_reverts = dt[
    rev_page %in% redirect_pages & 
    rev_user_text %in% c("DarknessBot", "Xqbot") & 
    reverting_user_text %in% c("DarknessBot", "Xqbot"),]
fight_reverts[
    order(fight_reverts$reverting_day),
    list(rev_page, rev_user_text, reverting_user_text, reverting_day, reverting_comment),]
# Out:
#    rev_page rev_user_text reverting_user_text reverting_day
# 1   3080753 Xqbot         DarknessBot         2009-09-15
# 2  15333324 Xqbot         DarknessBot         2009-09-15
# 3  13148847 Xqbot         DarknessBot         2009-09-15
# 4  18313488 Xqbot         DarknessBot         2009-09-15
# 5  18322006 Xqbot         DarknessBot         2009-09-15
# 6   2991127 Xqbot         DarknessBot         2009-09-15
# 7   2991195 Xqbot         DarknessBot         2009-09-15
# 8   2991200 Xqbot         DarknessBot         2009-09-15
# 9   2991205 Xqbot         DarknessBot         2009-09-15
# 10  2991208 Xqbot         DarknessBot         2009-09-15
# 11  2991211 Xqbot         DarknessBot         2009-09-15
# 12  2994450 Xqbot         DarknessBot         2009-09-15
# 13  2991127 Xqbot         DarknessBot         2009-09-15
# 14  2991195 Xqbot         DarknessBot         2009-09-15
# 15  2991200 Xqbot         DarknessBot         2009-09-15
# 16  2991205 Xqbot         DarknessBot         2009-09-15
# 17  2991208 Xqbot         DarknessBot         2009-09-15
# 18  2991211 Xqbot         DarknessBot         2009-09-15
# 19  2994450 Xqbot         DarknessBot         2009-09-15
# 20  3080753 Xqbot         DarknessBot         2009-09-15
# 21 13148847 Xqbot         DarknessBot         2009-09-15
# 22 15333324 Xqbot         DarknessBot         2009-09-15
# 23 18313488 Xqbot         DarknessBot         2009-09-15
# 24 18322006 Xqbot         DarknessBot         2009-09-15
# 25  3080753 DarknessBot   Xqbot               2009-10-02
# 26 15333324 DarknessBot   Xqbot               2009-10-02
# 27 13148847 DarknessBot   Xqbot               2009-10-02
# 28 18313488 DarknessBot   Xqbot               2009-10-02
# 29 18322006 DarknessBot   Xqbot               2009-10-02
# 30  2991127 DarknessBot   Xqbot               2009-10-02
# 31  2991200 DarknessBot   Xqbot               2009-10-02
# 32  2991205 DarknessBot   Xqbot               2009-10-02
# 33  2991208 DarknessBot   Xqbot               2009-10-02
# 34  2991211 DarknessBot   Xqbot               2009-10-02
# 35  2994450 DarknessBot   Xqbot               2009-10-02
# 36  2991127 DarknessBot   Xqbot               2009-10-02
# 37  2991200 DarknessBot   Xqbot               2009-10-02
# 38  2991205 DarknessBot   Xqbot               2009-10-02
# 39  2991208 DarknessBot   Xqbot               2009-10-02
# 40  2991211 DarknessBot   Xqbot               2009-10-02
# 41  2994450 DarknessBot   Xqbot               2009-10-02
# 42  3080753 DarknessBot   Xqbot               2009-10-02
# 43 13148847 DarknessBot   Xqbot               2009-10-02
# 44 15333324 DarknessBot   Xqbot               2009-10-02
# 45 18313488 DarknessBot   Xqbot               2009-10-02
# 46 18322006 DarknessBot   Xqbot               2009-10-02
#    reverting_comment
# 1  Fixing identified double redirect
# 2  Fixing identified double redirect
# 3  Fixing identified double redirect
# 4  Fixing identified double redirect
# 5  Fixing identified double redirect
# 6  Fixing identified double redirect
# 7  Fixing identified double redirect
# 8  Fixing identified double redirect
# 9  Fixing identified double redirect
# 10 Fixing identified double redirect
# 11 Fixing identified double redirect
# 12 Fixing identified double redirect
# 13 Fixing identified double redirect
# 14 Fixing identified double redirect
# 15 Fixing identified double redirect
# 16 Fixing identified double redirect
# 17 Fixing identified double redirect
# 18 Fixing identified double redirect
# 19 Fixing identified double redirect
# 20 Fixing identified double redirect
# 21 Fixing identified double redirect
# 22 Fixing identified double redirect
# 23 Fixing identified double redirect
# 24 Fixing identified double redirect
# 25 Robot: Fixing double redirect
# 26 Robot: Fixing double redirect
# 27 Robot: Fixing double redirect
# 28 Robot: Fixing double redirect
# 29 Robot: Fixing double redirect
# 30 Robot: Fixing double redirect
# 31 Robot: Fixing double redirect
# 32 Robot: Fixing double redirect
# 33 Robot: Fixing double redirect
# 34 Robot: Fixing double redirect
# 35 Robot: Fixing double redirect
# 36 Robot: Fixing double redirect
# 37 Robot: Fixing double redirect
# 38 Robot: Fixing double redirect
# 39 Robot: Fixing double redirect
# 40 Robot: Fixing double redirect
# 41 Robot: Fixing double redirect
# 42 Robot: Fixing double redirect
# 43 Robot: Fixing double redirect
# 44 Robot: Fixing double redirect
# 45 Robot: Fixing double redirect
# 46 Robot: Fixing double redirect

# %%
fight_reverts[
    order(fight_reverts$reverting_day),
    list(reverts=length(rev_page)),
    list(reverting_day, reverting_user_text, rev_user_text, reverting_comment)]
# Out:
#   reverting_day reverting_user_text rev_user_text
# 1 2009-09-15    DarknessBot         Xqbot
# 2 2009-10-02    Xqbot               DarknessBot
#   reverting_comment                 reverts
# 1 Fixing identified double redirect 24
# 2 Robot: Fixing double redirect     22
