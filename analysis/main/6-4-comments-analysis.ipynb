# %% [markdown]
# # Section 6.4: Coded comments analysis and possible botfights
#
# This is a data analysis script used to produce findings in the paper, which you can run based entirely off the files in this GitHub repository.
#
# This entire notebook can be run from the beginning with Kernel -> Restart & Run All in the menu bar. It takes about 2 minutes to run on a laptop running a Core i5-2540M processor.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import pickle
import datetime
# %matplotlib inline

# %%
start = datetime.datetime.now()

# %%
# !unxz --keep --force ../../datasets/parsed_dataframes/df_all_comments_parsed_2016.pickle.xz

# %%
with open("../../datasets/parsed_dataframes/df_all_comments_parsed_2016.pickle", "rb") as f:
    df_all = pickle.load(f)

# %%
len(df_all)
# Out:
# 924945

# %%
df_all_ns0 = df_all.query("page_namespace == 0")

# %%
counts_bottype_dict = {}
for lang in df_all_ns0['language'].unique():

    df_lang_ns0 = df_all_ns0[df_all_ns0['language']==lang]
    
    type_counts = df_lang_ns0['bottype'].value_counts().rename("count")
    type_percent = df_lang_ns0['bottype'].value_counts(normalize=True).rename("percent") * 100
    type_percent = type_percent.round(2).astype(str) + "%"

    counts_bottype_dict[lang]=pd.concat([type_counts, type_percent], axis=1)
    
counts_bottype_group_dict = {}

for lang in df_all_ns0['language'].unique():

    df_lang_ns0 = df_all_ns0[df_all_ns0['language']==lang]
    
    type_counts = df_lang_ns0['bottype_group'].value_counts().rename("count")
    type_percent = df_lang_ns0['bottype_group'].value_counts(normalize=True).rename("percent") * 100
    type_percent = type_percent.round(2).astype(str) + "%"

    counts_bottype_group_dict[lang]=pd.concat([type_counts, type_percent], axis=1)

# %%
counts_bottype_group_dict['en']
# Out:
#                                     count percent
# fixing double redirect             110513  45.15%
# interwiki link cleanup -- method1   83718   34.2%
# interwiki link cleanup -- method2   37085  15.15%
# botfight                             3408   1.39%
# protection template cleanup          2831   1.16%
# not classified                       2616   1.07%
# category work                        1779   0.73%
# template work                        1273   0.52%
# other w/ revert in comment           1009   0.41%
# other classified                      561   0.23%

# %%
gb_lang_bottype = df_all_ns0.groupby(["language", "bottype"])['revisions_reverted']
gb_lang_bottype_group = df_all_ns0.groupby(["language", "bottype_group"])['revisions_reverted']

# %%
gb_lang_bottype.count().unstack().transpose().replace(np.nan,0)
# Out:
# language                                              de        en       es  \
# bottype
# botfight: 718bot vs ImageRemovalBot                  1.0     170.0      0.0
# botfight: Cyberbot II vs AnomieBOT date tagging      0.0     301.0      0.0
# botfight: Russbot vs Cydebot category renaming      10.0    2095.0      0.0
# botfight: infoboxneeded                              0.0      98.0      0.0
# botfight: mathbot mathlist updates                   0.0     514.0      0.0
# botfight: reverting CommonsDelinker                  5.0     230.0     16.0
# category redirect cleanup                            1.0     337.0    106.0
# clearing sandbox                                     0.0       1.0      1.0
# commons image migration                              0.0       3.0      0.0
# fixing double redirect                             989.0  110513.0   9561.0
# fixing links                                         0.0      81.0      0.0
# interwiki link cleanup -- method1                16573.0   83718.0  16045.0
# interwiki link cleanup -- method2                35894.0   37085.0  37801.0
# moving category                                      7.0    1442.0      0.0
# other                                             1405.0    2616.0   3195.0
# other w/ per justification                          10.0     179.0    140.0
# other w/ revert in comment                          28.0    1009.0   1101.0
# protection template cleanup                         10.0    2831.0      0.0
# redirect tagging/sorting                             0.0     297.0      0.0
# template cleanup                                     5.0    1249.0    133.0
# template tagging                                     0.0      24.0      0.0
#
# language                                              fr       ja       pt  \
# bottype
# botfight: 718bot vs ImageRemovalBot                  0.0      0.0      0.0
# botfight: Cyberbot II vs AnomieBOT date tagging      0.0      0.0      0.0
# botfight: Russbot vs Cydebot category renaming       0.0      0.0      0.0
# botfight: infoboxneeded                              0.0      0.0      0.0
# botfight: mathbot mathlist updates                   0.0      0.0      0.0
# botfight: reverting CommonsDelinker                  2.0      0.0      1.0
# category redirect cleanup                            0.0      0.0      0.0
# clearing sandbox                                     2.0      0.0      1.0
# commons image migration                              0.0      0.0      0.0
# fixing double redirect                            3247.0    294.0   1888.0
# fixing links                                         0.0      0.0      0.0
# interwiki link cleanup -- method1                10082.0   5042.0  13626.0
# interwiki link cleanup -- method2                41154.0  27631.0  41576.0
# moving category                                    268.0      0.0      0.0
# other                                             1025.0   1787.0   2970.0
# other w/ per justification                         398.0      7.0     36.0
# other w/ revert in comment                           3.0     11.0     26.0
# protection template cleanup                          0.0      0.0      0.0
# redirect tagging/sorting                             0.0      0.0      0.0
# template cleanup                                     0.0      0.0      0.0
# template tagging                                     0.0      0.0      0.0
#
# language                                              zh
# bottype
# botfight: 718bot vs ImageRemovalBot                  0.0
# botfight: Cyberbot II vs AnomieBOT date tagging      0.0
# botfight: Russbot vs Cydebot category renaming       0.0
# botfight: infoboxneeded                              0.0
# botfight: mathbot mathlist updates                   0.0
# botfight: reverting CommonsDelinker                  3.0
# category redirect cleanup                            0.0
# clearing sandbox                                     0.0
# commons image migration                              0.0
# fixing double redirect                            3690.0
# fixing links                                         0.0
# interwiki link cleanup -- method1                14661.0
# interwiki link cleanup -- method2                23618.0
# moving category                                      0.0
# other                                              794.0
# other w/ per justification                           6.0
# other w/ revert in comment                         257.0
# protection template cleanup                          0.0
# redirect tagging/sorting                             0.0
# template cleanup                                     0.0
# template tagging                                     0.0

# %%
gb_lang_bottype_group.count().unstack().transpose().replace(np.nan,0).sort_values(by='en', ascending=False)
# Out:
# language                                de        en       es       fr  \
# bottype_group
# fixing double redirect               989.0  110513.0   9561.0   3247.0
# interwiki link cleanup -- method1  16573.0   83718.0  16045.0  10082.0
# interwiki link cleanup -- method2  35894.0   37085.0  37801.0  41154.0
# botfight                              16.0    3408.0     16.0      2.0
# protection template cleanup           10.0    2831.0      0.0      0.0
# not classified                      1405.0    2616.0   3195.0   1025.0
# category work                          8.0    1779.0    106.0    268.0
# template work                          5.0    1273.0    133.0      0.0
# other w/ revert in comment            28.0    1009.0   1101.0      3.0
# other classified                      10.0     561.0    141.0    400.0
#
# language                                ja       pt       zh
# bottype_group
# fixing double redirect               294.0   1888.0   3690.0
# interwiki link cleanup -- method1   5042.0  13626.0  14661.0
# interwiki link cleanup -- method2  27631.0  41576.0  23618.0
# botfight                               0.0      1.0      3.0
# protection template cleanup            0.0      0.0      0.0
# not classified                      1787.0   2970.0    794.0
# category work                          0.0      0.0      0.0
# template work                          0.0      0.0      0.0
# other w/ revert in comment            11.0     26.0    257.0
# other classified                       7.0     37.0      6.0

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
sns.set_palette("husl")
gb_lang_bottype_group.sum().unstack().transpose().plot(kind='barh')

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
sns.set_palette("husl")
gb_lang_bottype_group.sum().unstack().transpose().plot(kind='bar', subplots=False, figsize=[12,6])

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
sns.set_palette("husl")
gb_lang_bottype_group.sum().unstack().transpose().plot(kind='barh', subplots=False, figsize=[12,6])

plt.xscale("log")

# %% [markdown]
# ## Classified time to revert
# ### English, articles only

# %%
sns.set(font_scale=2)
pal = sns.color_palette("hls", 10)
g = sns.FacetGrid(df_all.query("page_namespace == 0 and language == 'en'"),
                  palette=pal, hue="bottype_group", size=8, aspect=2)
g.map(sns.kdeplot, "time_to_revert_hrs_log10")
#g.add_legend()
leg = plt.legend()
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

g.ax.set_xlim([np.log10(1/90), np.log10(24*365*5)])
    
g.ax.set_xticks([np.log10(1/60),np.log10(1), np.log10(24), np.log10(24*7), np.log10(24*30), np.log10(24*365)])
g.ax.set_xticklabels(["minute", "hour", "day", "week", "month", "year"])
# Out:
# [<matplotlib.text.Text at 0x7fda02a4f320>,
#  <matplotlib.text.Text at 0x7fda02a512b0>,
#  <matplotlib.text.Text at 0x7fda029fad68>,
#  <matplotlib.text.Text at 0x7fda029fd9e8>,
#  <matplotlib.text.Text at 0x7fda029fa7f0>,
#  <matplotlib.text.Text at 0x7fda02a01f28>]

# %% [markdown]
# ### All languages, articles only, KDE, combined plot

# %%
sns.set(font_scale=2)
pal = sns.color_palette("hls", 10)
g = sns.FacetGrid(df_all.query("page_namespace == 0"),
                  palette=pal, hue="bottype_group", size=8, aspect=2)
g.map(sns.kdeplot, "time_to_revert_hrs_log10")
#g.add_legend()
leg = plt.legend()
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

g.ax.set_xlim([np.log10(1/90), np.log10(24*365*5)])
    
g.ax.set_xticks([np.log10(1/60),np.log10(1), np.log10(24), np.log10(24*7), np.log10(24*30), np.log10(24*365)])
g.ax.set_xticklabels(["minute", "hour", "day", "week", "month", "year"])
# Out:
# [<matplotlib.text.Text at 0x7fda02dba748>,
#  <matplotlib.text.Text at 0x7fda02dc00b8>,
#  <matplotlib.text.Text at 0x7fda02d6ab00>,
#  <matplotlib.text.Text at 0x7fda02dcdeb8>,
#  <matplotlib.text.Text at 0x7fda031f0a90>,
#  <matplotlib.text.Text at 0x7fda03153fd0>]

# %% [markdown]
# ### All languages, articles only, panel plot, KDE only

# %%
sns.set(font_scale=2)
pal = sns.color_palette("husl", 7)
g = sns.FacetGrid(df_all.query("page_namespace == 0"),
                  palette=pal, row="bottype_group", size=3, aspect=4, sharex=False, sharey=False)
g.map(sns.kdeplot, "time_to_revert_hrs_log10")

xticks = [np.log10(1/60),np.log10(1), np.log10(24), np.log10(24*7), np.log10(24*30), np.log10(24*365)]
xticklabels = ["minute", "hour", "day", "week", "month", "year"]

for ax in g.axes.flatten():
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)
    ax.set_xlim(np.log10(1/90), np.log10(24*365*5))

# %% [markdown]
# ### All languages, articles only, paneled plot, KDE and histogram

# %%
sns.set(font_scale=2)
pal = sns.color_palette("husl", 7)
g = sns.FacetGrid(df_all.query("page_namespace == 0"),
                  palette=pal, row="bottype_group", size=3, aspect=4, sharex=False, sharey=False)
g.map(sns.distplot, "time_to_revert_hrs_log10")

xticks = [np.log10(1/60),np.log10(1), np.log10(24), np.log10(24*7), np.log10(24*30), np.log10(24*365)]
xticklabels = ["minute", "hour", "day", "week", "month", "year"]

for ax in g.axes.flatten():
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)
    ax.set_xlim(np.log10(1/90), np.log10(24*365*5))

# %% [markdown]
# ### Mean number of reverts per language per bottype

# %%
gb_group_per_page = df_all.query("page_namespace == 0").groupby(["language","bottype_group"])['reverts_per_page_botpair_sorted']

# %%
gb_group_per_page.mean().unstack()
# Out:
# bottype_group  botfight  category work  fixing double redirect  \
# language
# de             1.750000       2.750000                1.159757
# en             6.244425       1.201237                1.123424
# es             1.000000       1.000000                1.143395
# fr             1.000000       1.000000                1.033877
# ja                  NaN            NaN                1.071429
# pt             1.000000            NaN                1.069386
# zh             1.000000            NaN                1.157182
#
# bottype_group  interwiki link cleanup -- method1  \
# language
# de                                      1.000302
# en                                      1.000048
# es                                      1.000873
# fr                                      1.001488
# ja                                      1.002975
# pt                                      1.000661
# zh                                      1.000136
#
# bottype_group  interwiki link cleanup -- method2  not classified  \
# language
# de                                      1.170920        1.124555
# en                                      1.106350        2.682722
# es                                      1.115526        1.091706
# fr                                      1.119429        1.094634
# ja                                      1.192646        1.092334
# pt                                      1.135078        1.060943
# zh                                      1.206029        1.148615
#
# bottype_group  other classified  other w/ revert in comment  \
# language
# de                     1.200000                    1.035714
# en                     4.090909                    2.805748
# es                     1.000000                    1.015441
# fr                     1.002500                    1.666667
# ja                     1.000000                    1.363636
# pt                     1.000000                    1.192308
# zh                     1.333333                    1.513619
#
# bottype_group  protection template cleanup  template work
# language
# de                                1.000000       1.000000
# en                                1.116567       1.025923
# es                                     NaN       1.000000
# fr                                     NaN            NaN
# ja                                     NaN            NaN
# pt                                     NaN            NaN
# zh                                     NaN            NaN

# %% [markdown]
# ## Possible botfights

# %% [markdown]
# ### Number of reverts that are possible botfights, per language per bottype
#
# This only includes reverts with `reverts_per_page_botpair_sorted` > 1 (meaning they were not reciprocated by the reverted bot) and where the time to revert was less than 180 days.

# %%
df_all_ns0_multiple_reverts = df_all_ns0.query("reverts_per_page_botpair_sorted > 1 and time_to_revert_days < 180")
gb_lang_bottype_group_rr = df_all_ns0_multiple_reverts.groupby(["language", "bottype_group"])['revisions_reverted']

# %%
gb_lang_bottype_group_rr.count().unstack().transpose().replace(np.nan,0).sort_values(by='en', ascending=False)
# Out:
# language                               de      en      es      fr      ja  \
# bottype_group
# fixing double redirect              108.0  8925.0   690.0    86.0    20.0
# interwiki link cleanup -- method2  2906.0  2171.0  2284.0  2567.0  2059.0
# botfight                             10.0  1722.0     0.0     0.0     0.0
# not classified                       86.0   355.0   155.0    59.0   145.0
# category work                         6.0   350.0     0.0     0.0     0.0
# protection template cleanup           0.0   258.0     0.0     0.0     0.0
# other w/ revert in comment            1.0   168.0    12.0     2.0     4.0
# other classified                      1.0    97.0     0.0     1.0     0.0
# template work                         0.0    33.0     0.0     0.0     0.0
# interwiki link cleanup -- method1     2.0     4.0     4.0     6.0     4.0
#
# language                               pt      zh
# bottype_group
# fixing double redirect              113.0   446.0
# interwiki link cleanup -- method2  2318.0  2169.0
# botfight                              0.0     0.0
# not classified                       95.0    67.0
# category work                         0.0     0.0
# protection template cleanup           0.0     0.0
# other w/ revert in comment            5.0   121.0
# other classified                      0.0     2.0
# template work                         0.0     0.0
# interwiki link cleanup -- method1     3.0     2.0

# %% [markdown]
# Sum by language

# %%
gb_lang_bottype_group_rr.count().unstack().transpose().replace(np.nan,0).sort_values(by='en', ascending=False).sum()
# Out:
# language
# de     3120.0
# en    14083.0
# es     3145.0
# fr     2721.0
# ja     2232.0
# pt     2534.0
# zh     2807.0
# dtype: float64

# %% [markdown]
# Total number of reverts that are part of possible botfights

# %%
gb_lang_bottype_group_rr.count().unstack().transpose().replace(np.nan,0).sort_values(by='en', ascending=False).sum().sum()
# Out:
# 30642.0

# %% [markdown]
# ### Possible botfight plots

# %%
gb_lang_bottype_group_rr.count().unstack().transpose().replace(np.nan,0).sort_values(by='en', ascending=False).plot(kind='bar')

# %% [markdown]
# ## Export possible botfights

# %%
df_all_ns0_multiple_reverts.to_pickle("../../datasets/parsed_dataframes/possible_botfights.pickle")
df_all_ns0_multiple_reverts.to_csv("../../datasets/parsed_dataframes/possible_botfights.tsv", sep="\t")

# %%
# !xz -9 -e --keep ../../datasets/parsed_dataframes/possible_botfights.pickle
# !xz -9 -e --keep ../../datasets/parsed_dataframes/possible_botfights.tsv
# Out:
# xz: ../../datasets/parsed_dataframes/possible_botfights.pickle.xz: File exists
# xz: ../../datasets/parsed_dataframes/possible_botfights.tsv.xz: File exists

# %%
end = datetime.datetime.now()

time_to_run = end - start
minutes = int(time_to_run.seconds/60)
seconds = time_to_run.seconds % 60
print("Total runtime: ", minutes, "minutes, ", seconds, "seconds")
# Out:
# Total runtime:  1 minutes,  35 seconds
