# %% [markdown]
# # Full specification of the software package environment
#
# Using pip and conda for package management.

# %%
# %%bash
#
# pip freeze > pip-freeze.txt
# cat pip-freeze.txt
# Out:
# alabaster==0.7.10
# alembic==0.9.1
# anaconda-client==1.6.3
# anaconda-navigator==1.5.3
# anaconda-project==0.6.0
# apiclient==1.0.3
# argcomplete==1.8.2
# asn1crypto==0.22.0
# astroid==1.4.9
# astropy==1.3.2
# Babel==2.4.0
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.0
# bitarray==0.8.1
# blaze==0.10.1
# bleach==1.5.0
# bokeh==0.12.5
# boto==2.46.1
# Bottleneck==1.2.1
# cffi==1.10.0
# chardet==3.0.3
# chest==0.2.3
# click==6.7
# cloudpickle==0.2.2
# clyent==1.2.2
# colorama==0.3.9
# compare-requirements==0.2.1
# conda==4.3.21
# conda-build==2.1.15
# conda-verify==2.0.0
# configobj==5.0.6
# contextlib2==0.5.5
# cryptography==1.8.1
# cycler==0.10.0
# Cython==0.25.2
# cytoolz==0.8.2
# dask==0.14.3
# datashape==0.5.4
# decorator==4.0.11
# dill==0.2.6
# docopt==0.6.2
# docutils==0.13.1
# dynd==0.7.3.dev1
# entrypoints==0.2.2
# et-xmlfile==1.0.1
# fastcache==1.0.2
# fastcluster==1.1.23
# filelock==2.0.7
# Flask==0.12.1
# Flask-Cors==3.0.2
# geopy==1.11.0
# ...

# %%
# %%bash
#
# conda list > conda-list.txt
# cat conda-list.txt
# Out:
# # packages in environment at /home/staeiou/conda:
# #
# _license                  1.1                      py35_1
# _nb_ext_conf              0.3.0                    py35_0
# alabaster                 0.7.10                   py35_0
# alembic                   0.9.1                     <pip>
# anaconda                  custom                   py35_0
# anaconda-client           1.6.3                    py35_0
# anaconda-navigator        1.5.3                    py35_0
# anaconda-project          0.6.0                    py35_0
# apiclient                 1.0.3                     <pip>
# argcomplete               1.8.2                     <pip>
# argcomplete               1.0.0                    py35_1
# asn1crypto                0.22.0                   py35_0
# astroid                   1.4.9                    py35_0
# astropy                   1.3.2               np112py35_0
# babel                     2.4.0                    py35_0
# ...
